# %%
import sqlite3

# %%
conn = sqlite3.connect("fintrackai.db")

# %%
cur = conn.cursor()

# %%
cur.execute("select * from expenseprofile")
cur.fetchall()
# Out:
# [(1,
#   6,
#   8000.0,
#   5000.0,
#   7000.0,
#   10000.0,
#   30000.0,
#   6000.0,
#   4000.0,
#   2000.0,
#   3000.0,
#   5000.0,
#   2000.0,
#   '2026-03-31 18:07:36.061794')]

# %%
cur.execute('''
        CREATE TABLE USER(
            USER_ID INT PRIMARY KEY,
            USER_NAME VARCHAR(100),
            GENDER VARCHAR(10),
            EMAIL VARCHAR(100),
            PASSWORD HASH TEXT,
            CREATED_AT DATETIME
            )  
     ''')

# %%
conn.commit()

# %%
cur.execute('''
        CREATE TABLE VERIFICATION(
            OTP_ID INT PRIMARY KEY,
            USER_ID INT,
            EMAIL_OTP INT,
            OTP_EXP DATETIME,
            OTP_CREATION DATETIME,
            OTP_STATUS VARCHAR(30) CHECK(OTP_STATUS IN ("VERIFIED","NOT VERIFIED")),
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
            )  
     ''')

# %%
conn.commit()

# %%
cur.execute("DROP TABLE VERIFICATION")

# %%
cur.execute('''
        CREATE TABLE INCOMEPROFILE(
            PROFILE_ID INT PRIMARY KEY,
            USER_ID INT,
            INCOME_TYPE VARCHAR(40) CHECK(INCOME_TYPE IN("SALARIED","PROFESSIONAL","BUSINESS","OTHERS")),
            MONTHLY_INCOME FLOAT,
            ADDITIONAL_INCOME_TYPE VARCHAR(50) CHECK(ADDITIONAL_INCOME_TYPE IN("STOCK","INVESTEMENTS","BUSINESS","OTHERS")),
            ADDITIONAL_MONTHLY_INCOME FLOAT,
            DEPENDANTS INT CHECK(DEPENDANTS<20),
            CREATED_AT DATETIME,
            UPDATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
        )
        ''')

# %%
cur.execute('''
        CREATE TABLE EXPENSEPROFILE(
            EXPENSE_ID INT PRIMARY KEY,
            USER_ID INT,
            GROCERIES FLOAT,
            TRAVEL FLOAT,
            MEDFIT FLOAT,
            LEP FLOAT,
            MONTHLY_RENT FLOAT,
            M_BILLS FLOAT,
            FASHION FLOAT,
            ENTERTAINMENT FLOAT,
            EDUCATION FLOAT,
            EMSAVING FLOAT,
            MISCELLANEOUS FLOAT,
            CREATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID)
        )
        ''')

# %%
cur.execute('''
        CREATE TABLE GOALS(
            GOALID INT PRIMARY KEY,
            USER_ID INT,
            GOAL_NAME VARCHAR(100),
            START_DATE DATETIME,
            END_DATE DATETIME,
            GOAL_AMOUNT FLOAT,
            MONTHLY_SAVING_T FLOAT,
            GOAL_STATUS VARCHAR(50) CHECK(GOAL_STATUS IN("ACTIVE","PAUSED","ACHIEVED","EXPIRED","INACTIVE")),
            CREATED_AT DATETIME,
            UPDATED_AT DATETIME,
            FOREIGN KEY(USER_ID) REFERENCES USER(USER_ID))
            

     
        ''')

# %%
cur.execute('''
        CREATE TABLE GOAL_HISTORY(
        HISTORY_ID INT PRIMARY KEY,
        GOALID INT,
        CREATED_AT DATETIME,
        SAVE_MONTH FLOAT,
        FOREIGN KEY(GOALID) REFERENCES GOALS(GOALID))
     
        ''')

# %%
import sqlite3

# %%
conn = sqlite3.connect("fintrackai.db")

# %%
import datetime

# %%
import datetime
cur.execute(f'''
    INSERT INTO USER VALUES(1,"john","MALE","JOHN@GMAIL.COM","JHVCUYWFWEADT7F875JHV3296","{datetime.datetime.now()}")
        ''')

# %%
conn.commit()

# %%
cur.execute("SELECT * FROM USER")
cur.fetchall()
# Out:
# [(2,
#   'paul',
#   'MALE',
#   'PAUL@GMAIL.COM',
#   'JHVCUYWFWEFSADT7F875JHV3296',
#   '2026-03-26 18:20:42.408607'),
#  (1,
#   'john',
#   'MALE',
#   'JOHN@GMAIL.COM',
#   'JHVCUYWFWEADT7F875JHV3296',
#   '2026-03-26 18:24:55.408270'),
#  (3,
#   'Shaswat Mohapatra',
#   'Male',
#   'shaswatmohapatra5@gmail.com',
#   'scrypt:32768:8:1$2LmNJqxbz9ZIkqtd$48dcdaf15d94df193837825d5f94f897331081f77bcb06c9c356fdc146c5442f442d6f2bbeb086735aa57894816aaec8fd3c756c242c58251d16eaa3e86c34a9',
#   '2026-03-26 19:23:04.859966'),
#  (4,
#   'Situ',
#   'Male',
#   'tapasx@gmail.com',
#   'scrypt:32768:8:1$vEwHeGwyu7DTLTai$1864e8593da8e18e820b3f8c56a9e9925a692cd64e43940029d836f734f707381e6cb5b1e4aeda5c16ecd4a21c7de41db93f962a9819a0a7d5c4a56558f37554',
#   '2026-03-28 17:29:04.882951'),
#  (5,
#   'Atish',
#   'Male',
#   'atish@gmail.com',
#   'scrypt:32768:8:1$JIME4dAVO14VSN45$9f9a4d17531b09688692f4c61b3c77391ae8a3ac95465b78b6f4cca42c675ddd618b2d00aa93bcc26dbba2ce6d6b6022ca5b514979d41f591897d89c1fb1521b',
#   '2026-03-28 17:33:28.189593'),
#  (6,
#   'Shaasha',
#   'Male',
#   'entwinedotters26@gmail.com',
#   'scrypt:32768:8:1$sN8hHluPdWJagYQ6$7b5aa61f0d0f705dc10c703d91bb717dc9b26aa01f999f32cabb0674ecd9750269bb7d3b1eda4996c3c4a782f3d294ef62df75a1fdf87d9865277e1472add0da',
#   '2026-03-28 18:04:14.256278')]

# %%
cur.execute("INSERT INTO VERIFICATION VALUES(1,2,6057,1038464.56,'2025-03-04 15:20:30','VERIFIED')")
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 cur.execute("INSERT INTO VERIFICATION VALUES(1,2,6057,1038464.56,'2025-03-04 15:20:30','VERIFIED')")
#       2 conn.commit()
#
# IntegrityError: UNIQUE constraint failed: VERIFICATION.OTP_ID

# %%
cur.execute("select * from verification")
x = cur.fetchall()
x
# Out:
# [(1, 2, 6057, 1038464.56, '2025-03-04 15:20:30', 'VERIFIED'),
#  (2, 4, 6713, 1774699435.5375366, '2026-03-28 17:29:05.396647', 'VERIFIED'),
#  (3, 5, 7462, 1774699696.497473, '2026-03-28 17:33:28.600405', 'VERIFIED'),
#  (4, 6, 3896, 1774701496.2783725, '2026-03-28 18:04:14.652141', 'VERIFIED')]
